# %% [markdown]
# <a href="https://colab.research.google.com/github/mateuussilvapb/atividades_curso_AWS/blob/exercicio_1_javascript/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Na imagem abaixo temos diversos exemplos da utilização do JavaScript. É possível, sem problema algum, a montagem dos elementos em tela utilizando apenas HTML e CSS.
#
# Porém, as ações que os elementos em destaque realizam não são possíveis apenas com HTML e CSS:
# 1.   Criar uma lista de casamento: Para isso, é necessário que exista lógica de programação, como criação de variáveis, arrays, etc. Para além, caso o armazenamento das informações fosse feito de forma que o usuário pudesse fechar e abrir o site em outro computador e a lista de casamento fosse apresentada da mesma forma, ainda seria necessário também um back-end com configurações de persistência;
# 2.   O mesmo dito acima se aplica para o carrinho de compras;
# 3. Para entrar ou criar uma conta, também é necessário o uso de JavaScript pelos mesmos motivos: armazenamento de informações, comunicação com back-end, validação dos dados informados, etc;
#
#
#
# ![image.png](data:image/png;base64,...)
